# %%
# !pip install gensim

# %%
import nltk
from gensim.models import Word2Vec
nltk.download('punkt')

text = "Congress leader Rahul Gandhi on Friday expressed concern over reports of adulteration in the famed Tirupati laddu, a sacred offering distributed at the Sri Venkateshwara temple in Andhra Pradesh. Taking to social media, Gandhi called for a thorough investigation into the issue, stressing the need to maintain the sanctity of religious spaces."

sentences = nltk.sent_tokenize(text)  # Split text into sentences
tokenized_sentences = [nltk.word_tokenize(sentence.lower()) for sentence in sentences]  # Tokenize each sentence into words

model = Word2Vec(tokenized_sentences, vector_size=100, window=5, min_count=1, workers=4)

unique_words = set(word for sentence in tokenized_sentences for word in sentence)

for word in unique_words:
    similar_words = model.wv.most_similar(word, topn=5)
    print(f"Most similar words to '{word}':")
    for similar_word, similarity in similar_words:
        print(f"- {similar_word} (similarity: {similarity:.4f})")
    print()

model.save('word2vec.model')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Most similar words to 'a':
# - reports (similarity: 0.1785)
# - media (similarity: 0.1642)
# - . (similarity: 0.1313)
# - venkateshwara (similarity: 0.0775)
# - adulteration (similarity: 0.0747)
#
# Most similar words to 'gandhi':
# - offering (similarity: 0.2531)
# - sanctity (similarity: 0.2014)
# - taking (similarity: 0.1959)
# - issue (similarity: 0.1756)
# - of (similarity: 0.1707)
#
# Most similar words to 'stressing':
# - of (similarity: 0.1710)
# - sacred (similarity: 0.1365)
# - at (similarity: 0.1327)
# - temple (similarity: 0.1164)
# - laddu (similarity: 0.1031)
#
# Most similar words to 'thorough':
# - investigation (similarity: 0.1491)
# - concern (similarity: 0.0990)
# - taking (similarity: 0.0815)
# - expressed (similarity: 0.0687)
# - into (similarity: 0.0670)
#
# Most similar words to 'of':
# - temple (similarity: 0.2122)
# ...
